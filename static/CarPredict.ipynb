# %%
import numpy as np # type: ignore
import pandas as pd # type: ignore
import matplotlib.pyplot as plt # type: ignore
# %matplotlib inline
import seaborn as sns # type: ignore

import warnings
warnings.simplefilter("ignore")

# %%
data = pd.read_csv('CarPrice_Assignment.csv')
data.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop(columns=['car_ID'],inplace=True)
data.head()
# Out:
#    symboling                   CarName fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
data['enginelocation'].unique().tolist()
# Out:
# ['front', 'rear']

# %%
data.CarName.iloc[0]
# Out:
# 'alfa-romero giulia'

# %%
data.CarName.iloc[0].split()
# Out:
# ['alfa-romero', 'giulia']

# %%
data.CarName.iloc[0].split()[0]
# Out:
# 'alfa-romero'

# %%
data['CarCompanyName'] = data['CarName'].apply(lambda x:x.split()[0])

# %%
data['CarCompanyName'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
data.groupby('CarCompanyName')['CarCompanyName'].agg('count')
# Out:
# CarCompanyName
# Nissan          1
# alfa-romero     3
# audi            7
# bmw             8
# buick           8
# chevrolet       3
# dodge           9
# honda          13
# isuzu           4
# jaguar          3
# maxda           2
# mazda          15
# mercury         1
# mitsubishi     13
# nissan         17
# peugeot        11
# plymouth        7
# porcshce        1
# porsche         4
# renault         2
# saab            6
# subaru         12
# toyota         31
# toyouta         1
# vokswagen       1
# volkswagen      9
# volvo          11
# vw              2
# Name: CarCompanyName, dtype: int64

# %%
data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price',
#        'CarCompanyName'],
#       dtype='object')

# %%
data.drop(columns=['CarName'],inplace=True)
data.head()
# Out:
#    symboling fueltype aspiration doornumber      carbody drivewheel  \
# 0          3      gas        std        two  convertible        rwd
# 1          3      gas        std        two  convertible        rwd
# 2          1      gas        std        two    hatchback        rwd
# 3          2      gas        std       four        sedan        fwd
# 4          2      gas        std       four        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  fuelsystem  boreratio  \
# 0          front       88.6      168.8      64.1  ...        mpfi       3.47
# 1          front       88.6      168.8      64.1  ...        mpfi       3.47
# 2          front       94.5      171.2      65.5  ...        mpfi       2.68
# 3          front       99.8      176.6      66.2  ...        mpfi       3.19
# 4          front       99.4      176.6      66.4  ...        mpfi       3.19
#
#   stroke compressionratio  horsepower peakrpm  citympg  highwaympg    price  \
# ...

# %%
data["CarCompanyName"].replace("alfa-romero","alfa-romeo", inplace=True)
data["CarCompanyName"].replace("maxda","mazda", inplace=True)
data["CarCompanyName"].replace("Nissan","nissan", inplace=True)
data["CarCompanyName"].replace("porcshce","porsche", inplace=True)
data["CarCompanyName"].replace("toyouta","toyota", inplace=True)
data["CarCompanyName"].replace("porcshce","porsche", inplace=True)
data["CarCompanyName"].replace("vokswagen","volkswagen", inplace=True)
data["CarCompanyName"].replace("vw","volkswagen", inplace=True)

# %%
data['CarCompanyName'].unique()
# Out:
# array(['alfa-romeo', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
categorical_features = data.dtypes == object
list_categorical_features = data.columns[categorical_features].tolist()

# %%
list_categorical_features
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem',
#  'CarCompanyName']

# %%
data[list_categorical_features]
# Out:
#     fueltype aspiration doornumber      carbody drivewheel enginelocation  \
# 0        gas        std        two  convertible        rwd          front
# 1        gas        std        two  convertible        rwd          front
# 2        gas        std        two    hatchback        rwd          front
# 3        gas        std       four        sedan        fwd          front
# 4        gas        std       four        sedan        4wd          front
# ..       ...        ...        ...          ...        ...            ...
# 200      gas        std       four        sedan        rwd          front
# 201      gas      turbo       four        sedan        rwd          front
# 202      gas        std       four        sedan        rwd          front
# 203   diesel      turbo       four        sedan        rwd          front
# 204      gas      turbo       four        sedan        rwd          front
#
#     enginetype cylindernumber fuelsystem CarCompanyName
# ...

# %%
numerical_features = data.dtypes != object
list_numerical_features = data.columns[numerical_features].tolist()

# %%
list_numerical_features
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
data[list_numerical_features]
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0            3       88.6      168.8      64.1       48.8        2548
# 1            3       88.6      168.8      64.1       48.8        2548
# 2            1       94.5      171.2      65.5       52.4        2823
# 3            2       99.8      176.6      66.2       54.3        2337
# 4            2       99.4      176.6      66.4       54.3        2824
# ..         ...        ...        ...       ...        ...         ...
# 200         -1      109.1      188.8      68.9       55.5        2952
# 201         -1      109.1      188.8      68.8       55.5        3049
# 202         -1      109.1      188.8      68.9       55.5        3012
# 203         -1      109.1      188.8      68.9       55.5        3217
# 204         -1      109.1      188.8      68.9       55.5        3062
#
#      enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %%
data.shape
# Out:
# (205, 25)

# %%
categorical_features1 = data.dtypes==object
list_categorical_features1 = data.columns[categorical_features1].tolist()

# %%
list_categorical_features1
# Out:
# ['fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem',
#  'CarCompanyName']

# %%
numerical_features1 = data.dtypes!=object
list_numerical_features1 = data.columns[numerical_features1].tolist()

# %%
data.drop(columns=['aspiration','doornumber','drivewheel','enginelocation','cylindernumber','fuelsystem','boreratio','stroke','compressionratio','enginesize'],inplace=True)
data.head()
# Out:
#    symboling fueltype      carbody  wheelbase  carlength  carwidth  carheight  \
# 0          3      gas  convertible       88.6      168.8      64.1       48.8
# 1          3      gas  convertible       88.6      168.8      64.1       48.8
# 2          1      gas    hatchback       94.5      171.2      65.5       52.4
# 3          2      gas        sedan       99.8      176.6      66.2       54.3
# 4          2      gas        sedan       99.4      176.6      66.4       54.3
#
#    curbweight enginetype  horsepower  peakrpm  citympg  highwaympg    price  \
# 0        2548       dohc         111     5000       21          27  13495.0
# 1        2548       dohc         111     5000       21          27  16500.0
# 2        2823       ohcv         154     5000       19          26  16500.0
# 3        2337        ohc         102     5500       24          30  13950.0
# 4        2824        ohc         115     5500       18          22  17450.0
#
#   CarCompanyName
# 0     alfa-romeo
# ...

# %%
list_numerical_features1
# Out:
# ['symboling',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginesize',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
data3 = data.copy()

# %%
data3.head()
# Out:
#    symboling fueltype      carbody  wheelbase  carlength  carwidth  carheight  \
# 0          3      gas  convertible       88.6      168.8      64.1       48.8
# 1          3      gas  convertible       88.6      168.8      64.1       48.8
# 2          1      gas    hatchback       94.5      171.2      65.5       52.4
# 3          2      gas        sedan       99.8      176.6      66.2       54.3
# 4          2      gas        sedan       99.4      176.6      66.4       54.3
#
#    curbweight enginetype  horsepower  peakrpm  citympg  highwaympg    price  \
# 0        2548       dohc         111     5000       21          27  13495.0
# 1        2548       dohc         111     5000       21          27  16500.0
# 2        2823       ohcv         154     5000       19          26  16500.0
# 3        2337        ohc         102     5500       24          30  13950.0
# 4        2824        ohc         115     5500       18          22  17450.0
#
#   CarCompanyName
# 0     alfa-romeo
# ...

# %%
dummies = pd.get_dummies(data3[['fueltype','carbody','enginetype','CarCompanyName']])
dummies.head()
# Out:
#    fueltype_diesel  fueltype_gas  carbody_convertible  carbody_hardtop  \
# 0            False          True                 True            False
# 1            False          True                 True            False
# 2            False          True                False            False
# 3            False          True                False            False
# 4            False          True                False            False
#
#    carbody_hatchback  carbody_sedan  carbody_wagon  enginetype_dohc  \
# 0              False          False          False             True
# 1              False          False          False             True
# 2               True          False          False            False
# 3              False           True          False            False
# 4              False           True          False            False
#
#    enginetype_dohcv  enginetype_l  ...  CarCompanyName_nissan  \
# 0             False         False  ...                  False
# ...

# %%
data4 = pd.concat([data3,dummies],axis=1)
data4.head()
# Out:
#    symboling fueltype      carbody  wheelbase  carlength  carwidth  carheight  \
# 0          3      gas  convertible       88.6      168.8      64.1       48.8
# 1          3      gas  convertible       88.6      168.8      64.1       48.8
# 2          1      gas    hatchback       94.5      171.2      65.5       52.4
# 3          2      gas        sedan       99.8      176.6      66.2       54.3
# 4          2      gas        sedan       99.4      176.6      66.4       54.3
#
#    curbweight enginetype  horsepower  ...  CarCompanyName_nissan  \
# 0        2548       dohc         111  ...                  False
# 1        2548       dohc         111  ...                  False
# 2        2823       ohcv         154  ...                  False
# 3        2337        ohc         102  ...                  False
# 4        2824        ohc         115  ...                  False
#
#    CarCompanyName_peugeot  CarCompanyName_plymouth  CarCompanyName_porsche  \
# ...

# %%
data4.drop(columns=['fueltype','carbody','enginetype','CarCompanyName'],axis=1,inplace=True)
data4.head()
# Out:
#    symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          3       88.6      168.8      64.1       48.8        2548
# 1          3       88.6      168.8      64.1       48.8        2548
# 2          1       94.5      171.2      65.5       52.4        2823
# 3          2       99.8      176.6      66.2       54.3        2337
# 4          2       99.4      176.6      66.4       54.3        2824
#
#    horsepower  peakrpm  citympg  highwaympg  ...  CarCompanyName_nissan  \
# 0         111     5000       21          27  ...                  False
# 1         111     5000       21          27  ...                  False
# 2         154     5000       19          26  ...                  False
# 3         102     5500       24          30  ...                  False
# 4         115     5500       18          22  ...                  False
#
#    CarCompanyName_peugeot  CarCompanyName_plymouth  CarCompanyName_porsche  \
# ...

# %%
data4.head().T
# Out:
#                                  0        1        2        3        4
# symboling                        3        3        1        2        2
# wheelbase                     88.6     88.6     94.5     99.8     99.4
# carlength                    168.8    168.8    171.2    176.6    176.6
# carwidth                      64.1     64.1     65.5     66.2     66.4
# carheight                     48.8     48.8     52.4     54.3     54.3
# curbweight                    2548     2548     2823     2337     2824
# horsepower                     111      111      154      102      115
# peakrpm                       5000     5000     5000     5500     5500
# citympg                         21       21       19       24       18
# highwaympg                      27       27       26       30       22
# price                      13495.0  16500.0  16500.0  13950.0  17450.0
# fueltype_diesel              False    False    False    False    False
# ...

# %%
X = data4.drop(columns=['price'])
X
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0            3       88.6      168.8      64.1       48.8        2548
# 1            3       88.6      168.8      64.1       48.8        2548
# 2            1       94.5      171.2      65.5       52.4        2823
# 3            2       99.8      176.6      66.2       54.3        2337
# 4            2       99.4      176.6      66.4       54.3        2824
# ..         ...        ...        ...       ...        ...         ...
# 200         -1      109.1      188.8      68.9       55.5        2952
# 201         -1      109.1      188.8      68.8       55.5        3049
# 202         -1      109.1      188.8      68.9       55.5        3012
# 203         -1      109.1      188.8      68.9       55.5        3217
# 204         -1      109.1      188.8      68.9       55.5        3062
#
#      horsepower  peakrpm  citympg  highwaympg  ...  CarCompanyName_nissan  \
# ...

# %%
y = data4.price
y.head()
# Out:
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# Name: price, dtype: float64

# %%
'''X['doornumber'].replace({'two': 0, 'four': 1}, inplace=True)
X['aspiration'].replace({'std': 0, 'turbo':1}, inplace=True)
X['drivewheel'].replace({'rwd': 0, 'fwd': 1,'4wd':2}, inplace=True)
X['enginelocation'].replace({'front': 0,'rear':1},inplace=True)
X['fuelsystem'].replace({'mpfi':0,'2bbl':1,'idi':2,'1bbl':3,'spdi':4,'4bbl':5,'mfi':6,'spfi':7},inplace=True)
X['cylindernumber'].replace({'four':0,'six':1,'five':2,'eight':3,'two':4,'three':5,'twelve':6},inplace=True)
'''
X.info()
#X['cylindernumber'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   symboling                  205 non-null    int64
#  1   wheelbase                  205 non-null    float64
#  2   carlength                  205 non-null    float64
#  3   carwidth                   205 non-null    float64
#  4   carheight                  205 non-null    float64
#  5   curbweight                 205 non-null    int64
#  6   horsepower                 205 non-null    int64
#  7   peakrpm                    205 non-null    int64
#  8   citympg                    205 non-null    int64
#  9   highwaympg                 205 non-null    int64
#  10  fueltype_diesel            205 non-null    bool
#  11  fueltype_gas               205 non-null    bool
#  12  carbody_convertible        205 non-null    bool
# ...

# %%
from sklearn.model_selection import train_test_split # type: ignore
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
#X['drivewheel'].value_counts()
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   symboling                  205 non-null    int64
#  1   wheelbase                  205 non-null    float64
#  2   carlength                  205 non-null    float64
#  3   carwidth                   205 non-null    float64
#  4   carheight                  205 non-null    float64
#  5   curbweight                 205 non-null    int64
#  6   horsepower                 205 non-null    int64
#  7   peakrpm                    205 non-null    int64
#  8   citympg                    205 non-null    int64
#  9   highwaympg                 205 non-null    int64
#  10  fueltype_diesel            205 non-null    bool
#  11  fueltype_gas               205 non-null    bool
#  12  carbody_convertible        205 non-null    bool
# ...

# %%
from sklearn.linear_model import LinearRegression # type: ignore
lr = LinearRegression()
lr.fit(X_train,y_train)
lr.score(X_test,y_test)
# Out:
# 0.8385908278663613

# %%
from sklearn.tree import DecisionTreeRegressor # type: ignore
dt= DecisionTreeRegressor()
dt.fit(X_train,y_train)
dt.score(X_test,y_test)
# Out:
# 0.809682132964846

# %%
from sklearn.ensemble  import RandomForestRegressor # type: ignore
rm = RandomForestRegressor()
rm.fit(X_train,y_train)
rm.score(X_test,y_test)
# Out:
# 0.8748982255614903

# %%
from sklearn.model_selection import ShuffleSplit # type: ignore
from sklearn.model_selection import cross_val_score # type: ignore

cv = ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)

cross_val_score(LinearRegression(),X,y,cv=cv)
# Out:
# array([0.81364735, 0.88723086, 0.93755937, 0.86843285, 0.95286602])

# %%
from sklearn.model_selection import GridSearchCV # type: ignore

from sklearn.linear_model import Lasso # type: ignore
from sklearn.tree import DecisionTreeRegressor # type: ignore

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' :{
            'model' : LinearRegression(),
            'params': {
                'copy_X' : [True,False],
                'fit_intercept' : [True,False],
                'n_jobs': [None,1,2,4],
                'positive': [True,False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params' :{
                'alpha': [1,2],
                'selection': ['random','cyclic']
            }
        },
        'decision_tree' :{
            'model':DecisionTreeRegressor(),
            'params':{
                'criterion':['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'],config['params'],cv=cv,return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model' : algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })
        
    return pd.DataFrame(scores,columns=['model','best_score','best_params'])


find_best_model_using_gridsearchcv(X,y)
# Out:
#                model  best_score  \
# 0  linear_regression    0.891947
# 1              lasso    0.879633
# 2      decision_tree    0.847190
#
#                                          best_params
# 0  {'copy_X': True, 'fit_intercept': True, 'n_job...
# 1                {'alpha': 1, 'selection': 'random'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'ran...

# %%
def predict_price(CarCompanyName, fueltype, highwaympg, citympg, peakrpm, horsepower, curbweight, carheight, carwidth, carlength, wheelbase, symboling, X, lr):
    # Find the indices of the categorical variables
    CarCompanyName_index = np.where(X.columns == 'CarCompanyName_' + CarCompanyName)[0][0]
    fueltype_index = np.where(X.columns == 'fueltype_' + fueltype)[0][0]

    # Create feature vector
    x = np.zeros(len(X.columns))
    x[0] = symboling
    x[1] = wheelbase
    x[2] = carlength
    x[3] = carwidth
    x[4] = carheight
    x[5] = curbweight
    x[6] = horsepower
    x[7] = peakrpm
    x[8] = citympg
    x[9] = highwaympg
    
    # Set categorical variable indices to 1
    if CarCompanyName_index >= 0:
        x[CarCompanyName_index] = 1
    if fueltype_index >= 0:
        x[fueltype_index] = 1

  
    return lr.predict([x])[0]

# %%
from sklearn.model_selection import cross_val_score, train_test_split # type: ignore
def classify(model, X, y):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    # train the model
    model.fit(x_train, y_train)
    print("Accuracy:", model.score(x_test, y_test) * 100)
    
    # cross-validation
    score = cross_val_score(model, X, y, cv=5)
    print("Score:", np.mean(score)*100)

# %%
from pandas import DataFrame


DataFrame(data)
# Out:
#      symboling fueltype      carbody  wheelbase  carlength  carwidth  \
# 0            3      gas  convertible       88.6      168.8      64.1
# 1            3      gas  convertible       88.6      168.8      64.1
# 2            1      gas    hatchback       94.5      171.2      65.5
# 3            2      gas        sedan       99.8      176.6      66.2
# 4            2      gas        sedan       99.4      176.6      66.4
# ..         ...      ...          ...        ...        ...       ...
# 200         -1      gas        sedan      109.1      188.8      68.9
# 201         -1      gas        sedan      109.1      188.8      68.8
# 202         -1      gas        sedan      109.1      188.8      68.9
# 203         -1   diesel        sedan      109.1      188.8      68.9
# 204         -1      gas        sedan      109.1      188.8      68.9
#
#      carheight  curbweight enginetype  horsepower  peakrpm  citympg  \
# 0         48.8        2548       dohc         111     5000       21
# ...

# %%
from sklearn.linear_model import LinearRegression # type: ignore

line_classification=LinearRegression()
line_classification.fit(X_train, y_train)
y_prediction=line_classification.predict(X_test)

from sklearn.metrics import mean_squared_error # type: ignore
mean_squared_error(y_test, y_prediction)
# Out:
# 8342201.674045294

# %%
predict_price
# Out:
# <function __main__.predict_price(CarCompanyName, fueltype, highwaympg, citympg, peakrpm, horsepower, curbweight, carheight, carwidth, carlength, wheelbase, symboling, X, lr)>

# %%
predicted_price = predict_price('audi', 'gas',20,20,3000,100,2000,45.6,66.5,234.5,75.5,7,X,rm)
print("Predicted price:", predicted_price)
# Out:
# Predicted price: 10973.035

# %%
predict_price= predict_price('alfa-romeo','diesel',27,21,5000,111,2548,48.8,64.1,168.8,88.6,3,X,rm)
print("Predicted price:", predicted_price)
# Out:
# Predicted price: 10973.035
